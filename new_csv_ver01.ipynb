# %%
import pandas as pd
import import_ipynb
from basic import *

df = pd.read_csv('./dataset/2023bigcontest_advanced_sac.csv')
df.head()
# Out:
# importing Jupyter notebook from basic.ipynb
#     age gender membership_type_1 membership_type_2 membership_type_3  \
# 0  50.0      F                골드                무료                그린
# 1   NaN    NaN               NaN               NaN               NaN
# 2   NaN    NaN               NaN               NaN               NaN
# 3   NaN    NaN               NaN               NaN               NaN
# 4  50.0      M                무료               NaN               NaN
#
#   membership_type_4 membership_type_5  membership_type_6  tran_date  \
# 0               NaN               NaN                NaN   20220114
# 1               NaN               NaN                NaN   20211003
# 2               NaN               NaN                NaN   20220917
# 3               NaN               NaN                NaN   20190630
# 4               NaN               NaN                NaN   20220206
#
#    tran_time  play_date  play_st_time          seat   price  ticket_cancel  \
# 0       1512   20220204          2000    3층 BOX9 10   10000              2
# 1       1550   20211009          2000       1층 7열 5       0              0
# 2       1520   20221105          2000  1층 C블록 16열 3       0              0
# 3       1132   20190731          2000       1층 2열 3       0              0
# 4       1615   20220302          1930   1층 B블록12열 7  180000              0
#
#   discount_type  performance_code  pre_open_date   open_date genre   place  \
# 0            일반               302     20220114.0  20220115.0   교향곡    콘서트홀
# 1           초대권              1120            NaN  20210823.0    독주   리사이틀홀
# 2           초대권              2283     20220911.0  20220911.0    독주  IBK챔버홀
# 3           초대권              2798            NaN  20190701.0    독주   리사이틀홀
# 4            일반               897     20220109.0  20220110.0    독주    콘서트홀
#
#    running_time  intermission member_yn
# 0           120            15         Y
# 1            90            15         N
# 2            80            15         N
# 3            90            15         N
# 4            90             0         Y

# %%
df1 = tran_rank_dense(date_preprocess(df))
df2 = sep_discount(sep_seat(df1))
df3 = error_member_yn(df2)
df4 = membership_col_make(labeling(df3))
df5 = genre_nan(age_nan(df4))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/anaconda3/envs/sac_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:171, in pandas._libs.index.IndexEngine.get_loc()
#
# KeyError: 24
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/lora/Documents/GitHub/SAC/new_csv_ver01.ipynb 셀 2 line 4
#       <a href='vscode-notebook-cell:/Users/lora/Documents/GitHub/SAC/new_csv_ver01.ipynb#W1sZmlsZQ%3D%3D?line=1'>2</a> df2 = sep_discount(sep_seat(df1))
#       <a href='vscode-notebook-cell:/Users/lora/Documents/GitHub/SAC/new_csv_ver01.ipynb#W1sZmlsZQ%3D%3D?line=2'>3</a> df3 = error_member_yn(df2)
# ----> <a href='vscode-notebook-cell:/Users/lora/Documents/GitHub/SAC/new_csv_ver01.ipynb#W1sZmlsZQ%3D%3D?line=3'>4</a> df4 = membership_col_make(labeling(df3))
#       <a href='vscode-notebook-cell:/Users/lora/Documents/GitHub/SAC/new_csv_ver01.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a> df5 = genre_nan(age_nan(df4))
#
# File <string>:11, in labeling(df)
#
# File /opt/homebrew/anaconda3/envs/sac_env/lib/python3.10/site-packages/pandas/core/series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File /opt/homebrew/anaconda3/envs/sac_env/lib/python3.10/site-packages/pandas/core/series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File /opt/homebrew/anaconda3/envs/sac_env/lib/python3.10/site-packages/pandas/core/indexes/base.py:3797, in Index.get_loc(self, key)
#    3792     if isinstance(casted_key, slice) or (
#    3793         isinstance(casted_key, abc.Iterable)
#    3794         and any(isinstance(x, slice) for x in casted_key)
#    3795     ):
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#    3802     self._check_indexing_error(key)
#
# KeyError: 24

# %%
df2.sample(5)
# Out:
#           age gender membership_type_1 membership_type_2 membership_type_3  \
# 672371    NaN    NaN               NaN               NaN               NaN
# 1586921   NaN    NaN               NaN               NaN               NaN
# 399858    NaN    NaN               NaN               NaN               NaN
# 45932    10.0      M                골드                무료              싹틔우미
# 1312273   NaN    NaN               NaN               NaN               NaN
#
#         membership_type_4 membership_type_5  membership_type_6   price  \
# 672371                NaN               NaN                NaN       0
# 1586921               NaN               NaN                NaN       0
# 399858                NaN               NaN                NaN       0
# 45932                 NaN               NaN                NaN  140000
# 1312273               NaN               NaN                NaN       0
#
#          ticket_cancel  performance_code  pre_open_date  open_date genre  \
# 672371               0              1071              1 2022-05-15    독주
# 1586921              0               330              1 2019-08-09   실내악
# 399858               0              2418              1 2018-12-03    독주
# 45932                0               877              1 2021-04-10   교향곡
# 1312273              2              2592              0 2023-05-06   실내악
#
#           place  running_time  intermission member_yn                tran  \
# 672371    리사이틀홀            90            15         N 2022-06-06 16:06:00
# 1586921  IBK챔버홀           100            15         N 2019-09-11 19:34:00
# 399858   IBK챔버홀            90            15         N 2018-12-09 17:03:00
# 45932      콘서트홀           120            15         Y 2021-05-13 22:41:00
# 1312273   리사이틀홀            90            15         N 2023-05-26 12:59:00
#
#         tran_day                play play_day  tran_rank  seat_floor  \
# 672371       월요일 2022-06-12 16:06:00      일요일       10.0           1
# 1586921      수요일 2019-09-15 19:34:00      일요일       24.0           1
# 399858       일요일 2018-12-16 17:03:00      일요일        3.0           1
# 45932        목요일 2021-06-05 22:41:00      토요일      101.0           1
# 1312273      금요일 2023-05-30 12:59:00      화요일       26.0           2
#
#         seat_block  seat_col  seat_num discount_name  discount_rate
# 672371          -1        10         7           초대권            100
# 1586921          B         9         6           초대권            100
# 399858           C         5         1           초대권            100
# 45932            C        17        13       골드회원 할인             30
# 1312273         -1         3        12         기획사판매            100

# %%
df2.isnull().sum()
# Out:
# age                  1293146
# gender               1292735
# membership_type_1    1292735
# membership_type_2    1423688
# membership_type_3    1731887
# membership_type_4    1871338
# membership_type_5    1899835
# membership_type_6    1901085
# price                      0
# ticket_cancel              0
# performance_code           0
# pre_open_date              0
# open_date                340
# genre                  25574
# place                      0
# running_time               0
# intermission               0
# member_yn                  0
# tran                       0
# tran_day                   0
# play                       0
# play_day                   0
# tran_rank                  0
# seat_floor                 0
# seat_block                 0
# seat_col                   0
# seat_num                   0
# discount_name              0
# discount_rate              0
# dtype: int64

# %%
# csv로 저장
df??.to_csv('sac_ver01.csv',index='False')

# %%
# df04.query('`place` == "콘서트홀" and `performance_code` == 302 and `discount_rate(%)` == "0"').price.unique()
# Out:
# array([ 10000,  50000, 120000,  90000], dtype=int64)

# %%
# df04.query('`genre` != `genre`')['performance_code'].unique()
# Out:
# array([ 229, 2818,  352, 1221, 2816, 2819,  988, 2215,   47,  588,  852,
#        1405, 2937,  354, 2472, 1751], dtype=int64)

# %%
# df04.performance_code.nunique()
# Out:
# 2931
